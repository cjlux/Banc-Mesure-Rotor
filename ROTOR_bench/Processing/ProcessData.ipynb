# %% [markdown]
# Banc de mesure du champ magnétique d'un rotor de moteur électrique

# %%
import numpy as np
import os
from stat import ST_CTIME
from tools import get_files_by_date, plot_magField_at_positions
from plot_ROTOR import plot_ROTOR

# %% [markdown]
# ## Data processing

# %%
working_dir = '/home/rotor/Banc-Mesure-Rotor'
os.chdir(working_dir)
print(f'Working in directory: <{os.getcwd()}>')
# Out:
# Working in directory: </home/rotor/Banc-Mesure-Rotor>

# %%
data_dir = './TXT'
list_file = [f for f in os.listdir(data_dir) if f.lower().endswith('.txt') and f.startswith('ROTOR')]
list_file.sort()

for i, file in enumerate(list_file):
    print(f'{os.path.join(data_dir, file)}')
# Out:
# ./TXT/ROTOR_2024-07-08-18-40_WDIST-1_ROTSTEP-120.0_001_012_1of1.txt
# ./TXT/ROTOR_2024-07-08-18-45_WDIST-1_ROTSTEP-1.2_030_1of1.txt
# ./TXT/ROTOR_2024-07-08-18-52_WDIST-1_ROTSTEP-1.2_1of1.txt
# ./TXT/ROTOR_2024-07-09-15-38_WDIST-1_ROTSTEP-60.0_050_1of1.txt
# ./TXT/ROTOR_2024-07-09-17-10_WDIST-20_ROTSTEP-2.4_010_040_070_1of1.txt
# ./TXT/ROTOR_2024-07-09-17-17_WDIST-20_ROTSTEP-120.0_010_1of1.txt
# ./TXT/ROTOR_2024-07-09-17-21_WDIST-20_ROTSTEP-120.0_010_1of1.txt
# ./TXT/ROTOR_2024-07-09-17-22_WDIST-20_ROTSTEP-120.0_010_1of1.txt
# ./TXT/ROTOR_2024-07-09-17-26_WDIST-20_ROTSTEP-120.0_010_1of1.txt
# ./TXT/ROTOR_2024-07-09-17-27_WDIST-20_ROTSTEP-120.0_010_1of1.txt
# ./TXT/ROTOR_2024-07-09-17-31_WDIST-20_ROTSTEP-120.0_010_1of1.txt
# ./TXT/ROTOR_2024-07-09-17-35_WDIST-20_ROTSTEP-120.0_010_1of1.txt
# ./TXT/ROTOR_2024-07-09-17-36_WDIST-20_ROTSTEP-120.0_010_1of1.txt
# ./TXT/ROTOR_2024-07-09-17-37_WDIST-20_ROTSTEP-90.0_010_1of1.txt
# ./TXT/ROTOR_2024-07-09-17-38_WDIST-20_ROTSTEP-90.0_010_1of1.txt
# ...

# %%
file_name= "./TXT/ROTOR_2024-11-07-14-31_WDIST-5_ROTSTEP-2.4_000_015_030_045_060_075_090_1of1.txt"

# %%
plot_ROTOR(file_name)
# Out:
# Plot ByAngle
