# %% [markdown]
# Banc de mesure du champ magnétique d'un rotor de moteur électrique

# %%
import numpy as np
import os
from stat import ST_CTIME
from tools import get_files_by_date, read_file, plot_magField_at_positions, user_choose_file

# %% [markdown]
# ## Data processing

# %%
data_dir = '../'
fileName, DATA, nb_Z_pos = user_choose_file(data_dir)

# transpose DATA to exxtract the different variables:
A, magnField = DATA.T[0], DATA.T[1:]

# plot the data
plot_magField_at_positions(A, magnField, nb_Z_pos, fileName, figsize=(10,8))
# Out:
#  0 -> ../06181047.TXT
# Fichier choisi [Q -> Quit]: 0
